# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('Metadata_Country.csv')
df1
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 5            ALB       Europe & Central Asia  Upper middle income
# 6            AND       Europe & Central Asia          High income
# 7            ARB                         NaN                  NaN
# 8            ARE  Middle East & North Africa          High income
# 9            ARG   Latin America & Caribbean  Upper middle income
# 10           ARM       Europe & Central Asia  Upper middle income
# 11           ASM         East Asia & Pacific          High income
# 12           ATG   Latin America & Caribbean          High income
# 13           AUS         East Asia & Pacific          High income
# 14           AUT       Europe & Central Asia          High income
# 15           AZE       Europe & Central Asia  Upper middle income
# 16           BDI          Sub-Saharan Africa           Low income
# 17           BEL       Europe & Central Asia          High income
# 18           BEN          Sub-Saharan Africa  Lower middle income
# 19           BFA          Sub-Saharan Africa           Low income
# 20           BGD                  South Asia  Lower middle income
# 21           BGR       Europe & Central Asia  Upper middle income
# 22           BHR  Middle East & North Africa          High income
# 23           BHS   Latin America & Caribbean          High income
# 24           BIH       Europe & Central Asia  Upper middle income
# 25           BLR       Europe & Central Asia  Upper middle income
# 26           BLZ   Latin America & Caribbean  Upper middle income
# 27           BMU               North America          High income
# 28           BOL   Latin America & Caribbean  Lower middle income
# 29           BRA   Latin America & Caribbean  Upper middle income
# ..           ...                         ...                  ...
# 235          TLA                         NaN                  NaN
# 236          TLS         East Asia & Pacific  Lower middle income
# 237          TMN                         NaN                  NaN
# 238          TON         East Asia & Pacific  Upper middle income
# 239          TSA                         NaN                  NaN
# 240          TSS                         NaN                  NaN
# 241          TTO   Latin America & Caribbean          High income
# 242          TUN  Middle East & North Africa  Lower middle income
# 243          TUR       Europe & Central Asia  Upper middle income
# 244          TUV         East Asia & Pacific  Upper middle income
# 245          TZA          Sub-Saharan Africa  Lower middle income
# 246          UGA          Sub-Saharan Africa           Low income
# 247          UKR       Europe & Central Asia  Lower middle income
# 248          UMC                         NaN                  NaN
# 249          URY   Latin America & Caribbean          High income
# 250          USA               North America          High income
# 251          UZB       Europe & Central Asia  Lower middle income
# 252          VCT   Latin America & Caribbean  Upper middle income
# 253          VEN   Latin America & Caribbean                  NaN
# 254          VGB   Latin America & Caribbean          High income
# 255          VIR   Latin America & Caribbean          High income
# 256          VNM         East Asia & Pacific  Lower middle income
# 257          VUT         East Asia & Pacific  Lower middle income
# 258          WLD                         NaN                  NaN
# 259          WSM         East Asia & Pacific  Lower middle income
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# 5                                                  NaN
# 6                                                  NaN
# 7    Arab World aggregate. Arab World is composed o...
# 8                                                  NaN
# 9    The World Bank systematically assesses the app...
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13   The reporting period for national accounts dat...
# 14   A simple multiplier is used to convert the nat...
# 15                                                 NaN
# 16   The World Bank systematically assesses the app...
# 17   A simple multiplier is used to convert the nat...
# 18                                                 NaN
# 19                                                 NaN
# 20   The reporting period for national accounts dat...
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25   Data before 2015 were adjusted to reflect the ...
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 235  Latin America & the Caribbean (IDA & IBRD coun...
# 236                                                NaN
# 237  Middle East & North Africa (IDA & IBRD countri...
# 238  The reporting period for national accounts dat...
# 239       South Asia (IDA & IBRD countries) aggregate.
# 240  Sub-Saharan Africa (IDA & IBRD countries) aggr...
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
# 246  The reporting period for national accounts dat...
# 247                                                NaN
# 248  Upper middle income group aggregate. Upper-mid...
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
# 259  The reporting period for national accounts dat...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                                    TableName
# 0                                      Aruba
# 1                Africa Eastern and Southern
# 2                                Afghanistan
# 3                 Africa Western and Central
# 4                                     Angola
# 5                                    Albania
# 6                                    Andorra
# 7                                 Arab World
# 8                       United Arab Emirates
# 9                                  Argentina
# 10                                   Armenia
# 11                            American Samoa
# 12                       Antigua and Barbuda
# 13                                 Australia
# 14                                   Austria
# 15                                Azerbaijan
# 16                                   Burundi
# 17                                   Belgium
# 18                                     Benin
# 19                              Burkina Faso
# 20                                Bangladesh
# 21                                  Bulgaria
# 22                                   Bahrain
# 23                              Bahamas, The
# 24                    Bosnia and Herzegovina
# 25                                   Belarus
# 26                                    Belize
# 27                                   Bermuda
# 28                                   Bolivia
# 29                                    Brazil
# ..                                       ...
# 235   Latin America & Caribbean (IDA & IBRD)
# 236                              Timor-Leste
# 237  Middle East & North Africa (IDA & IBRD)
# 238                                    Tonga
# 239                  South Asia (IDA & IBRD)
# 240          Sub-Saharan Africa (IDA & IBRD)
# 241                      Trinidad and Tobago
# 242                                  Tunisia
# 243                                  Türkiye
# 244                                   Tuvalu
# 245                                 Tanzania
# 246                                   Uganda
# 247                                  Ukraine
# 248                      Upper middle income
# 249                                  Uruguay
# 250                            United States
# 251                               Uzbekistan
# 252           St. Vincent and the Grenadines
# 253                            Venezuela, RB
# 254                   British Virgin Islands
# 255                    Virgin Islands (U.S.)
# 256                                 Viet Nam
# 257                                  Vanuatu
# 258                                    World
# 259                                    Samoa
# 260                                   Kosovo
# 261                              Yemen, Rep.
# 262                             South Africa
# 263                                   Zambia
# 264                                 Zimbabwe
#
# [265 rows x 5 columns]

# %%
gender_counts=df1['Region'].value_counts()
bar_width=0.9
x=range(len(gender_counts.index))
plt.bar(gender_counts.index,gender_counts.values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Region')
plt.xticks(x,gender_counts.index,rotation=45)
plt.tight_layout()
plt.show()

# %%
df1.shape
# Out:
# (265, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
# Country Code    265 non-null object
# Region          217 non-null object
# IncomeGroup     216 non-null object
# SpecialNotes    126 non-null object
# TableName       265 non-null object
# dtypes: object(5)
# memory usage: 10.4+ KB

# %%
df1.describe()
# Out:
#        Country Code                 Region  IncomeGroup  \
# count           265                    217          216
# unique          265                      7            4
# top             AFE  Europe & Central Asia  High income
# freq              1                     58           82
#
#                                              SpecialNotes TableName
# count                                                 126       265
# unique                                                111       265
# top     The reporting period for national accounts dat...  Malaysia
# freq                                                    7         1

# %%
df1.isnull().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
# Country Code    265 non-null object
# Region          217 non-null object
# IncomeGroup     216 non-null object
# SpecialNotes    126 non-null object
# TableName       265 non-null object
# dtypes: object(5)
# memory usage: 10.4+ KB
